# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes = True)

# %%
hulu = pd.read_csv("C:/Users/14753/Downloads/archive (1)/titles.csv")
hulu
# Out:
#              id                                              title   type  \
# 0       ts20475                                Saturday Night Live   SHOW
# 1       ts20413                                            M*A*S*H   SHOW
# 2       ts20005                                        I Love Lucy   SHOW
# 3       ts20669                                               Taxi   SHOW
# 4       ts21049                          The Mary Tyler Moore Show   SHOW
# ...         ...                                                ...    ...
# 2393   ts290117                        Nine Films About Technology   SHOW
# 2394   ts330263                                       Adoption Day   SHOW
# 2395   ts317705                   Candified: Home For The Holidays   SHOW
# 2396  tm1018386  The United States vs. Billie Holiday Special: ...  MOVIE
# 2397  tm1111028      Madagascar: A Little Wild Holiday Goose Chase  MOVIE
#
#                                             description  release_year  \
# ...

# %%
hulu_data = hulu.describe()
hulu_data
# Out:
#        release_year      runtime      seasons   imdb_score     imdb_votes  \
# count   2398.000000  2398.000000  1330.000000  2232.000000    2231.000000
# mean    2013.417014    61.518766     3.936090     6.699149   28286.883909
# std        8.483634    35.102738     5.020168     1.208236   78020.103846
# min     1951.000000     0.000000     1.000000     1.000000       5.000000
# 25%     2010.000000    25.000000     1.000000     5.900000     621.500000
# 50%     2016.000000    48.000000     2.000000     6.800000    3451.000000
# 75%     2019.000000    93.000000     5.000000     7.600000   17056.000000
# max     2022.000000   229.000000    63.000000     9.500000  996056.000000
#
#        tmdb_popularity   tmdb_score
# count      2348.000000  2238.000000
# mean         27.870533     6.885657
# std          91.997761     1.215606
# min           0.272976     1.000000
# 25%           4.789250     6.100000
# 50%          10.703000     7.000000
# 75%          23.910250     7.700000
# ...

# %%
hulu.dtypes
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %%
df = pd.DataFrame(hulu)

# %%
plt.figure(figsize=(25, 6))
sns.countplot(x='release_year', data=df)
plt.title('Count of Shows/Movies by Release Year')
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.show()

# %%
# Scatter Plot and Correlation between IMDb Score and TMDB Score
plt.figure(figsize=(8, 6))
sns.scatterplot(x='imdb_score', y='tmdb_score', data=df)
plt.title('Scatter Plot: IMDb Score vs TMDB Score')
plt.xlabel('IMDb Score')
plt.ylabel('TMDB Score')
plt.show()

# %%
# Boxplot
plt.figure(figsize=(25, 6))
sns.boxplot(x='release_year', y='imdb_score', data=df)
plt.title('Boxplot of IMDb Scores by Release Year')
plt.xlabel('Release Year')
plt.ylabel('IMDb Score')
plt.show()

# %%
# Other statistics
print("Min IMDb Score:", df['imdb_score'].min())
print("Max IMDb Score:", df['imdb_score'].max())
print("Mode of Release Year:", df['release_year'].mode()[0])
print("Mean IMDb Score:", df['imdb_score'].mean())
print("Median IMDb Score:", df['imdb_score'].median())
print("Range of Runtime:", df['runtime'].max() - df['runtime'].min())
print("Standard Deviation of IMDb Votes:", df['imdb_votes'].std())
print("Correlation between IMDb Score and TMDB Score:")
print(df['imdb_score'].corr(df['tmdb_score']))
# Out:
# Min IMDb Score: 1.0
# Max IMDb Score: 9.5
# Mode of Release Year: 2019
# Mean IMDb Score: 6.699148745519714
# Median IMDb Score: 6.8
# Range of Runtime: 229
# Standard Deviation of IMDb Votes: 78020.103845636
# Correlation between IMDb Score and TMDB Score:
# 0.6255125855318963

# %%
# Creating a DataFrame from the provided data
df = pd.DataFrame(hulu)

# Calculating average runtime for each year
average_runtime_by_year = df.groupby('release_year')['runtime'].mean().reset_index()

# Calculating mean and median of runtime
mean_runtime = df['runtime'].mean()
median_runtime = df['runtime'].median()

# Plotting the bar graph
plt.figure(figsize=(20, 6))
plt.bar(average_runtime_by_year['release_year'], average_runtime_by_year['runtime'], color='skyblue')
plt.axhline(mean_runtime, color='red', linestyle='--', label='Mean')  # Plotting mean as a dashed red line
plt.axhline(median_runtime, color='green', linestyle='-', label='Median')  # Plotting median as a solid green line
plt.title('Average Runtime Over Different Years')
plt.xlabel('Release Year')
plt.ylabel('Average Runtime')
plt.xticks(average_runtime_by_year['release_year'])
plt.legend()
plt.grid(axis='y')
plt.show()

# %%
# Creating a DataFrame from simulated data
df = pd.DataFrame(hulu)

# Calculating mean, median, and quartiles for runtime grouped by release_year
runtime_stats = df.groupby('release_year')['runtime'].describe(percentiles=[.25, .75])

# Plotting the line chart
plt.figure(figsize=(10, 6))

# Line plot for mean runtime per release year
plt.plot(runtime_stats['mean'], marker='o', label='Mean Runtime')

# Line plot for median runtime per release year
plt.plot(runtime_stats['50%'], marker='o', label='Median Runtime')

# Plotting the quartiles (25th-75th percentiles) as a shaded region
plt.fill_between(runtime_stats.index, runtime_stats['25%'], runtime_stats['75%'], alpha=0.3, label='25th-75th Percentiles')

plt.title('Mean, Median, and Quartiles of Runtime Across Release Years')
plt.xlabel('Release Year')
plt.ylabel('Runtime')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Creating a DataFrame from simulated data
df = pd.DataFrame(hulu)

# Calculating mean, median, and quartiles for imdb_score grouped by release_year
imdb_stats = df.groupby('release_year')['imdb_score'].describe(percentiles=[.25, .75])

# Plotting the line chart
plt.figure(figsize=(10, 6))

# Line plot for mean IMDb score per release year
plt.plot(imdb_stats['mean'], marker='o', label='Mean IMDb Score')

# Line plot for median IMDb score per release year
plt.plot(imdb_stats['50%'], marker='o', label='Median IMDb Score')

# Plotting the quartiles (25th-75th percentiles) as a shaded region
plt.fill_between(imdb_stats.index, imdb_stats['25%'], imdb_stats['75%'], alpha=0.3, label='25th-75th Percentiles')

plt.title('Mean, Median, and Quartiles of IMDb Scores Across Release Years')
plt.xlabel('Release Year')
plt.ylabel('IMDb Score')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Creating a DataFrame from simulated data
df = pd.DataFrame(hulu)

# Calculating mean, median, and quartiles for tmdb_score grouped by release_year
tmdb_stats = df.groupby('release_year')['tmdb_score'].describe(percentiles=[.25, .75])

# Plotting the line chart
plt.figure(figsize=(10, 6))

# Line plot for mean tmdb_score per release year
plt.plot(tmdb_stats['mean'], marker='o', label='Mean TMDb Score')

# Line plot for median tmdb_score per release year
plt.plot(tmdb_stats['50%'], marker='o', label='Median TMDb Score')

# Plotting the quartiles (25th-75th percentiles) as a shaded region
plt.fill_between(tmdb_stats.index, tmdb_stats['25%'], tmdb_stats['75%'], alpha=0.3, label='25th-75th Percentiles')

plt.title('Mean, Median, and Quartiles of TMDb Scores Across Release Years')
plt.xlabel('Release Year')
plt.ylabel('TMDb Score')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Creating a DataFrame from simulated data
df = pd.DataFrame(hulu)

# Calculating mean, median, and quartiles for imdb_score and tmdb_score
imdb_stats = df['imdb_score'].describe(percentiles=[.25, .75])
tmdb_stats = df['tmdb_score'].describe(percentiles=[.25, .75])

# Plotting the line chart
plt.figure(figsize=(10, 6))

# Line plot for mean IMDb score
plt.plot([imdb_stats['mean']] * 2, linestyle='--', color='blue', label='Mean IMDb Score')

# Line plot for median IMDb score
plt.plot([imdb_stats['50%']] * 2, linestyle='-', color='green', label='Median IMDb Score')

# Plotting the quartiles (25th-75th percentiles) for IMDb score
plt.fill_between([0, 1], imdb_stats['25%'], imdb_stats['75%'], alpha=0.3, color='yellow', label='25th-75th Percentiles IMDb Score')

# Line plot for mean TMDb score
plt.plot([tmdb_stats['mean']] * 2, linestyle='--', color='red', label='Mean TMDb Score')

# Line plot for median TMDb score
plt.plot([tmdb_stats['50%']] * 2, linestyle='-', color='orange', label='Median TMDb Score')

# Plotting the quartiles (25th-75th percentiles) for TMDb score
plt.fill_between([0, 1], tmdb_stats['25%'], tmdb_stats['75%'], alpha=0.3, color='purple', label='25th-75th Percentiles TMDb Score')

plt.title('Mean, Median, and Quartiles of IMDb and TMDb Scores')
plt.xticks([0, 1], ['IMDb Score', 'TMDb Score'])
plt.ylabel('Scores')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Creating a DataFrame from simulated data
df = pd.DataFrame(hulu)

# Calculating mean, median, and quartiles for votes grouped by release_year
votes_stats = df.groupby('release_year').describe(percentiles=[.25, .75])

# Plotting the line chart
plt.figure(figsize=(10, 6))

# Line plot for mean IMDb votes per release year
plt.plot(votes_stats['imdb_votes']['mean'], marker='o', label='Mean IMDb Votes')

# Line plot for median IMDb votes per release year
plt.plot(votes_stats['imdb_votes']['50%'], marker='o', label='Median IMDb Votes')

# Plotting the quartiles (25th-75th percentiles) for IMDb votes
plt.fill_between(votes_stats.index, votes_stats['imdb_votes']['25%'], votes_stats['imdb_votes']['75%'], alpha=0.3, label='25th-75th Percentiles IMDb Votes')

# Line plot for mean TMDb votes per release year
plt.plot(votes_stats['tmdb_score']['mean'], marker='o', linestyle='--', label='Mean TMDb score')

# Line plot for median TMDb votes per release year
plt.plot(votes_stats['tmdb_score']['50%'], marker='o', linestyle='--', label='Median TMDb score')

# Plotting the quartiles (25th-75th percentiles) for TMDb votes
plt.fill_between(votes_stats.index, votes_stats['tmdb_score']['25%'], votes_stats['tmdb_score']['75%'], alpha=0.3, label='25th-75th Percentiles TMDb score')

plt.title('Mean, Median, and Quartiles of IMDb and TMDb score Across Release Years')
plt.xlabel('Release Year')
plt.ylabel('Votes')
plt.legend()
plt.grid(True)
plt.show()

# %%
g=sns.relplot(x='release_year',y='imdb_score',data=hulu,hue='type',style='type')
g.fig.set_size_inches(10,5)
plt.show()

# %%
from sklearn import metrics
import math
import sklearn
import statistics

# %%
hulus = hulu[['release_year', 'runtime',
       'seasons', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
       'tmdb_score']]

# %%
hulus.head()
# Out:
#    release_year  runtime  seasons  imdb_score  imdb_votes  tmdb_popularity  \
# 0          1975       89     47.0         8.0     47910.0           54.345
# 1          1972       26     11.0         8.4     55882.0           27.308
# 2          1951       30      9.0         8.5     25944.0           17.088
# 3          1978       25      5.0         7.7     13379.0           14.346
# 4          1970       28      7.0         8.2      8692.0            9.290
#
#    tmdb_score
# 0         6.9
# 1         8.0
# 2         8.1
# 3         7.3
# 4         7.5

# %%
# Import sklearn 
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_validate
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.inspection import permutation_importance
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
# Dropping rows with any missing values
hullu = hulus.dropna()
hullu
# Out:
#       release_year  runtime  seasons  imdb_score  imdb_votes  tmdb_popularity  \
# 0             1975       89     47.0         8.0     47910.0           54.345
# 1             1972       26     11.0         8.4     55882.0           27.308
# 2             1951       30      9.0         8.5     25944.0           17.088
# 3             1978       25      5.0         7.7     13379.0           14.346
# 4             1970       28      7.0         8.2      8692.0            9.290
# ...            ...      ...      ...         ...         ...              ...
# 2367          2021       43      1.0         4.2       275.0            1.400
# 2373          2021       33      1.0         7.7      1673.0            1.400
# 2380          2021       49      1.0         4.6       115.0            0.682
# 2382          2021       77      1.0         8.6         7.0            0.600
# 2393          2021       11      1.0         7.3       182.0            1.683
#
#       tmdb_score
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
X = hullu.iloc[:,:-6].values
X
# Out:
# array([[1975],
#        [1972],
#        [1951],
#        ...,
#        [2021],
#        [2021],
#        [2021]], dtype=int64)

# %%
y = hullu.iloc[:,1].values
y
# Out:
# array([89, 26, 30, ..., 49, 77, 11], dtype=int64)

# %%
X_train,X_test,y_train,y_test = train_test_split (X,y,test_size= 0.3, random_state = 0)
X_train,X_test,y_train,y_test
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_train = reg.predict(X_train)
print("Train R2")

print(r2_score(y_train, y_pred_train))
y_pred_lr_reg = reg.predict(X_test)
print("Test R2")
r2_score(y_test, y_pred_lr_reg)
# Out:
# Train R2
# 0.0030531714921741004
# Test R2
# -0.00652378515213381

# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import GridSearchCV


# Define the hyperparameters and their possible values
param_grid = {'alpha': [0.1, 1, 10]}

# Create a Ridge or Lasso regressor
ridge_reg = Ridge()
lasso_reg = Lasso()

# Use GridSearchCV to evaluate different combinations of hyperparameters
grid_search_ridge = GridSearchCV(ridge_reg, param_grid, cv=5)
grid_search_ridge.fit(X_train, y_train)

grid_search_lasso = GridSearchCV(lasso_reg, param_grid, cv=5)
grid_search_lasso.fit(X_train, y_train)

# Print the best hyperparameters
print("Best hyperparameters for Ridge:", grid_search_ridge.best_params_)
print("Best hyperparameters for Lasso:", grid_search_lasso.best_params_)

print("*******. Ridge Regression ********")
y_predict=grid_search_ridge.predict(X_test)
y_predict_train=grid_search_ridge.predict(X_train)

print(' Train r2_score',r2_score(y_train,y_predict_train))

print(' Test r2_score',r2_score(y_test,y_predict))


print("******* Lasso  Regression ********")


y_predict=grid_search_lasso.predict(X_test)
y_predict_train=grid_search_lasso.predict(X_train)

print('Train r2_score',r2_score(y_train,y_predict_train))

print('  Test r2_score',r2_score(y_test,y_predict))
# Out:
# Best hyperparameters for Ridge: {'alpha': 10}
# Best hyperparameters for Lasso: {'alpha': 0.1}
# *******. Ridge Regression ********
#  Train r2_score 0.0030531713972477004
#  Test r2_score -0.006523786136330978
# ******* Lasso  Regression ********
# Train r2_score 0.003052415722606394
#   Test r2_score -0.006524821432379646

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (800, 1)
# (800,)

# %%
plt.scatter(X_train, y_train,color ='red')
plt.plot(X_train,reg.predict(X_train),color='blue')
plt.title("Linear Regression runtime vs release_year")
plt.xlabel("release_years")
plt.ylabel("Runtime")
# Out:
# Text(0, 0.5, 'Runtime')

# %%
plt.scatter(X_test, y_test,color ='red')
plt.plot(X_test,reg.predict(X_test),color='blue')
plt.title("Linear Regression runtime vs release_year")
plt.xlabel("release_years")
plt.ylabel("Runtime")
# Out:
# Text(0, 0.5, 'Runtime')

# %%
#RANDOM FOREST

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor(n_estimators=110,random_state=1)
forest.fit(X_train,y_train)

y_predict=forest.predict(X_test)
y_predict_train=forest.predict(X_train)

print('Random Forest Train r2_score',r2_score(y_train,y_predict_train))

print('Random Forest Test r2_score',r2_score(y_test,y_predict))
# Out:
# Random Forest Train r2_score 0.0810932649940227
# Random Forest Test r2_score -0.049981929288680504

# %%
#HYPER PARAMETER TUNING FOR RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Create a Random Forest regressor object
rf_regressor = RandomForestRegressor(random_state=42)

# Define the grid search parameters
param_grid = {
    'n_estimators': [100, 200, 500],
    'max_depth': [5, 10, 20],
    'max_features': ['sqrt', 'log2']
}

# Create a grid search object
grid_search = GridSearchCV(
    estimator=rf_regressor, param_grid=param_grid, cv=5, n_jobs=-1)

# Fit the grid search object to the data
grid_search.fit(X_train, y_train)

# Print the best hyperparameters
print("Best parameters:", grid_search.best_params_)

y_predict=grid_search.predict(X_test)
y_predict_train=grid_search.predict(X_train)

print('Random Forest Train r2_score',r2_score(y_train,y_predict_train))

print('Random Forest Test r2_score',r2_score(y_test,y_predict))
# Out:
# Best parameters: {'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200}
# Random Forest Train r2_score 0.07251952938053119
# Random Forest Test r2_score -0.03571639158610718

# %%
#ADA BOOST

# %%
from sklearn.ensemble import AdaBoostRegressor
ada_boost = AdaBoostRegressor(n_estimators=57, learning_rate=0.05, loss='exponential')
ada_boost.fit(X_train,y_train)

y_pred_ada_boost = ada_boost.predict(X_test)
y_pred_ada_train = ada_boost.predict(X_train)

print('Ada Boost Test r2_score',r2_score(y_test, y_pred_ada_boost))
print('Ada Boost Train r2_score',r2_score(y_train, y_pred_ada_train))
# Out:
# Ada Boost Test r2_score -0.003257485143689287
# Ada Boost Train r2_score 0.04102009566609177

# %%
#HYPER PARAMETER FOR ADA BOOST

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor



# Create a Decision Tree regressor object
base_regressor = DecisionTreeRegressor()

# Create an AdaBoost regressor object
ada_regressor = AdaBoostRegressor(
    base_estimator=base_regressor, random_state=42)

# Define the grid search parameters
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 1],
    'base_estimator__max_depth': [5, 10, 20]
}

# Create a grid search object
grid_search = GridSearchCV(
    estimator=ada_regressor, param_grid=param_grid, cv=5, n_jobs=-1)

# Fit the grid search object to the data
grid_search.fit(X_train, y_train)

# Print the best hyperparameters
print("Best parameters:", grid_search.best_params_)


y_predict=grid_search.predict(X_test)
y_predict_train=grid_search.predict(X_train)

print('Ada Boost  Train r2_score',r2_score(y_train,y_predict_train))

print('Ada Boost Test r2_score',r2_score(y_test,y_predict))
# Out:
# Best parameters: {'base_estimator__max_depth': 5, 'learning_rate': 0.01, 'n_estimators': 100}
# Ada Boost  Train r2_score 0.07812928250547013
# Ada Boost Test r2_score -0.02891262252723359

# %%
# Use Gradient Boost 
from sklearn.ensemble import GradientBoostingRegressor
gb_m = GradientBoostingRegressor(n_estimators=247, max_depth=6, learning_rate=0.3)
gb_m.fit(X_train,y_train)
y_pred_gb_train = gb_m.predict(X_train)
print('Gradient Boost Train r2_score',r2_score(y_train, y_pred_gb_train))
y_pred_gb = gb_m.predict(X_test)
print('Gradient Boost Test r2_score',r2_score(y_test, y_pred_gb))
# Out:
# Gradient Boost Train r2_score 0.08895633290138161
# Gradient Boost Test r2_score -0.04765523311734299

# %%
from xgboost import XGBRegressor
xgbr = XGBRegressor()
xgbr.fit(X_train,y_train)

y_predict=xgbr.predict(X_test)
y_predict_train=xgbr.predict(X_train)

print(' Extra Gradient Boosting   Train r2_score',r2_score(y_train,y_predict_train))

print('Extra Gradient Boosting  Test r2_score',r2_score(y_test,y_predict))
# Out:
#  Extra Gradient Boosting   Train r2_score 0.08895633210459586
# Extra Gradient Boosting  Test r2_score -0.06562689814976652

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, train_test_split


# Define the XGBoost model
model = xgb.XGBRegressor()

# Define the hyperparameters to tune and their ranges
param_grid = {
    'learning_rate': [0.01, 0.1, 0.5],
    'max_depth': [3, 5, 7],
    'n_estimators': [50, 100, 200]
}

# Perform grid search cross-validation to find the best hyperparameters
grid_search = GridSearchCV(
    estimator=model, param_grid=param_grid, scoring='r2', cv=5, n_jobs=-1)
grid_result = grid_search.fit(X_train, y_train)

# Print the best hyperparameters and R-squared score on the test set
print("Best Hyperparameters:", grid_result.best_params_)


y_predict=grid_search.predict(X_test)
y_predict_train=grid_search.predict(X_train)

print(' Extra Gradient Boosting   Train r2_score',r2_score(y_train,y_predict_train))

print('Extra Gradient Boosting  Test r2_score',r2_score(y_test,y_predict))
# Out:
# Best Hyperparameters: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}
#  Extra Gradient Boosting   Train r2_score 0.04178473412395467
# Extra Gradient Boosting  Test r2_score -0.008780014890866328
