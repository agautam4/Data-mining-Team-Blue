# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hulu = pd.read_csv("C:/Users/14753/Downloads/archive (1)/titles.csv")
hulu
# Out:
#              id                                              title   type  \
# 0       ts20475                                Saturday Night Live   SHOW
# 1       ts20413                                            M*A*S*H   SHOW
# 2       ts20005                                        I Love Lucy   SHOW
# 3       ts20669                                               Taxi   SHOW
# 4       ts21049                          The Mary Tyler Moore Show   SHOW
# ...         ...                                                ...    ...
# 2393   ts290117                        Nine Films About Technology   SHOW
# 2394   ts330263                                       Adoption Day   SHOW
# 2395   ts317705                   Candified: Home For The Holidays   SHOW
# 2396  tm1018386  The United States vs. Billie Holiday Special: ...  MOVIE
# 2397  tm1111028      Madagascar: A Little Wild Holiday Goose Chase  MOVIE
#
#                                             description  release_year  \
# ...

# %%
hulu.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
hulu_data = hulu[['title', 'type','release_year',
       'age_certification', 'runtime',
       'seasons', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
       'tmdb_score']]
hulu_data
# Out:
#                                                   title   type  release_year  \
# 0                                   Saturday Night Live   SHOW          1975
# 1                                               M*A*S*H   SHOW          1972
# 2                                           I Love Lucy   SHOW          1951
# 3                                                  Taxi   SHOW          1978
# 4                             The Mary Tyler Moore Show   SHOW          1970
# ...                                                 ...    ...           ...
# 2393                        Nine Films About Technology   SHOW          2021
# 2394                                       Adoption Day   SHOW          2021
# 2395                   Candified: Home For The Holidays   SHOW          2021
# 2396  The United States vs. Billie Holiday Special: ...  MOVIE          2021
# 2397      Madagascar: A Little Wild Holiday Goose Chase  MOVIE          2021
#
# ...

# %%
hulu_data.isna().sum()
# Out:
# title                   0
# type                    0
# release_year            0
# age_certification     685
# runtime                 0
# seasons              1068
# imdb_score            166
# imdb_votes            167
# tmdb_popularity        50
# tmdb_score            160
# dtype: int64

# %%
hulu_data.describe()
# Out:
#        release_year      runtime      seasons   imdb_score     imdb_votes  \
# count   2398.000000  2398.000000  1330.000000  2232.000000    2231.000000
# mean    2013.417014    61.518766     3.936090     6.699149   28286.883909
# std        8.483634    35.102738     5.020168     1.208236   78020.103846
# min     1951.000000     0.000000     1.000000     1.000000       5.000000
# 25%     2010.000000    25.000000     1.000000     5.900000     621.500000
# 50%     2016.000000    48.000000     2.000000     6.800000    3451.000000
# 75%     2019.000000    93.000000     5.000000     7.600000   17056.000000
# max     2022.000000   229.000000    63.000000     9.500000  996056.000000
#
#        tmdb_popularity   tmdb_score
# count      2348.000000  2238.000000
# mean         27.870533     6.885657
# std          91.997761     1.215606
# min           0.272976     1.000000
# 25%           4.789250     6.100000
# 50%          10.703000     7.000000
# 75%          23.910250     7.700000
# ...

# %%
hulu_data.dtypes
# Out:
# title                 object
# type                  object
# release_year           int64
# age_certification     object
# runtime                int64
# seasons              float64
# imdb_score           float64
# imdb_votes           float64
# tmdb_popularity      float64
# tmdb_score           float64
# dtype: object

# %%
hulu_data.hist(bins=60,figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'release_year'}>,
#         <Axes: title={'center': 'runtime'}>,
#         <Axes: title={'center': 'seasons'}>],
#        [<Axes: title={'center': 'imdb_score'}>,
#         <Axes: title={'center': 'imdb_votes'}>,
#         <Axes: title={'center': 'tmdb_popularity'}>],
#        [<Axes: title={'center': 'tmdb_score'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
long_form=hulu_data[hulu_data['runtime']>50]

# %%
long_form[['release_year','imdb_score']].plot(kind='scatter',x='release_year',y='imdb_score',figsize=(10,8))
# Out:
# <Axes: xlabel='release_year', ylabel='imdb_score'>

# %%
g=sns.relplot(x='release_year',y='imdb_score',data=long_form,hue='type',style='type')
g.fig.set_size_inches(10,5)
plt.show()

# %%
pd.DataFrame(hulu_data['runtime'].value_counts()).plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
short_form=hulu_data[hulu_data['runtime']<50]

# %%
short_form[['release_year','imdb_score']].plot(kind='scatter',x='release_year',y='imdb_score',figsize=(10,8))
# Out:
# <Axes: xlabel='release_year', ylabel='imdb_score'>

# %%
g=sns.relplot(x='release_year',y='imdb_score',data=short_form,hue='type',style='type')
g.fig.set_size_inches(10,5)
plt.show()

# %%
# !pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.1 MB 991.0 kB/s eta 0:00:10
#     --------------------------------------- 0.2/9.1 MB 2.3 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/9.1 MB 2.6 MB/s eta 0:00:04
#    -- ------------------------------------- 0.5/9.1 MB 2.9 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/9.1 MB 2.9 MB/s eta 0:00:03
#    --- ------------------------------------ 0.8/9.1 MB 2.9 MB/s eta 0:00:03
#    --- ------------------------------------ 0.9/9.1 MB 3.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/9.1 MB 2.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.2/9.1 MB 3.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.4/9.1 MB 3.1 MB/s eta 0:00:03
#    ------ --------------------------------- 1.5/9.1 MB 3.1 MB/s eta 0:00:03
# ...

# %%
from sklearn import linear_model

# %%
print (hulu_data.head(10))       # display first 10 entries
print(hulu_data.shape)           # display the dimensions of the dataset (rows and columns)
print(hulu_data.columns.values)  #display columns names
hulu_data.info()
# Out:
#                        title   type  release_year age_certification  runtime  \
# 0        Saturday Night Live   SHOW          1975             TV-14       89
# 1                    M*A*S*H   SHOW          1972             TV-PG       26
# 2                I Love Lucy   SHOW          1951              TV-G       30
# 3                       Taxi   SHOW          1978             TV-PG       25
# 4  The Mary Tyler Moore Show   SHOW          1970             TV-PG       28
# 5            The Brady Bunch   SHOW          1969              TV-G       25
# 6       The Bob Newhart Show   SHOW          1972             TV-PG       27
# 7              Lost in Space   SHOW          1965             TV-PG       50
# 8             The Odd Couple   SHOW          1970               NaN       27
# 9                  The Lorax  MOVIE          1972                PG       25
#
#    seasons  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# ...

# %%
#Scatter plot : Plot the scatter plot of yearly average_co2_concentrations variable 

hulu_data.plot.scatter(x="release_year",y="runtime")
plt.xlabel('Year') 
plt.ylabel('runtime') 
plt.title ('runtime of shows in different years')
plt.show()

# %%
# Use NumPy library to convert the DataFrame to NumPy Array which would be used in the further steps. 
x=[]
y=[]
x=hulu_data['release_year'].to_numpy()
y=hulu_data['runtime'].to_numpy()
n = np.size(x)  # number of observations/points

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from sklearn import metrics
import math
import sklearn
import statistics

# %%
# Function: Calculate Regression Coefficients : b0 is Y-intercept and b1 is slope for a Regression Line b0 + b1*x  
def estimate_coef(x, y): 
     
    # mean of x and y vector 
    m_x, m_y = np.mean(x), np.mean(y) 
  
    # calculating cross-deviation and deviation about x 
    SS_xy = np.sum(y*x) - n*m_y*m_x 
    SS_xx = np.sum(x*x) - n*m_x*m_x 
  
   
    b_1 = SS_xy / SS_xx 
    b_0 = m_y - b_1*m_x 
  
    return(b_0, b_1) 
  
# Function: Plot the scatter plot and Regression Line as per the predicted coefficients
def plot_regression_line(x, y, b): 
    # plotting the actual points as scatter plot 
    plt.scatter(x, y, color = "m", 
               marker = "o", s = 30) 
  
    # predicted response vector 
    y_pred = b[0] + b[1]*x 
      
    # plot the regression line 
    plt.plot(x, y_pred, color = "g") 
# prepare and render the scatter plot 
    plt.xlabel('release_year') 
    plt.ylabel('runtime') 
    plt.title ('runtime of shows in different years and Linear Regression')     
    plt.show() 

# Function: Calculate RMSE (Root Mean-Squared Error values)    
def rmse(b,y):
    predict=[]
    for i in range(0,n):
        predict.append(b[0]+b[1]*x[i])
    predict=np.array(predict)    
    mse = sklearn.metrics.mean_squared_error(y, predict)
    root_mse = math.sqrt(mse)                       # RMSE value
    nrmse = root_mse/statistics.mean(y)             # Normalized RMSE value
    return(root_mse,nrmse)

# Function: Call the functions in a particular order
def main(x,y): 
    # Estimate Regression Coefficients 
    b = estimate_coef(x, y) 
    print("Estimated coefficients of the line y = b0 + b1*x are:\nb0 = {}   \nb1 = {}".format(b[0], b[1])) 
      
    # Plot regression line 
    residual_error = rmse(b,y)
    print("RMSE VALUE is",residual_error[0])
    print("Normalized RMSE VALUE is",residual_error[1])
    plot_regression_line(x, y, b)

#Call the main function    
if __name__ == "__main__": 
         main(x,y)

#EoF
# Out:
# Estimated coefficients of the line y = b0 + b1*x are:
# b0 = -902.7865859385371
# b1 = 0.4789397053794275
# RMSE VALUE is 34.85951879954559
# Normalized RMSE VALUE is 0.5714675213040261
